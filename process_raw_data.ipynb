# %%
import pandas as pd
import os

# %%
# Folder to read all files from
raw_folder = "11-19-2021 4pm ET"
# Get list of file names in folder
file_list = os.listdir(raw_folder)
# Loop over files in folder and combine to one dataframe
df = pd.DataFrame()
for file in file_list:
    # Read in file
    file_df = pd.read_csv(raw_folder+'/'+file)
    # Combine to one dataframe
    df = df.append(file_df)
df
# Out:
#                                            Name  Wait Time  Delivery Fee  \
# 0                    Philly's Best (Jingletown)        NaN          6.49
# 1                        Dirty Burger (Oakland)  60–70 min          6.49
# 2         Toasty's Breakfast Burritos (Oakland)  60–70 min          6.49
# 3               Burger Latino (5333 Adeline St)  45–55 min          6.49
# 4                    LIL BURMA (2353 E 12th St)  55–65 min          6.49
# ...                                         ...        ...           ...
# 2744        Mr. Pickle's Sandwich Shop - Newark  45–55 min         13.99
# 2745                        Cupcakin’ Bake Shop  50–60 min         13.99
# 2746                        Poke Bar - Berkeley  50–60 min         13.99
# 2747  Five Guys CA-1624 2254 South Shore Center  50–60 min          5.99
# 2748                                     TP Tea  50–60 min         13.99
#
#                                                    Link  \
# 0     https://postmates.com/store/phillys-best-jingl...
# 1     https://postmates.com/store/dirty-burger-oakla...
# 2     https://postmates.com/store/toastys-breakfast-...
# 3     https://postmates.com/store/burger-latino-5333...
# 4     https://postmates.com/store/lil-burma-2353-e-1...
# ...                                                 ...
# 2744  https://postmates.com/store/mr-pickles-sandwic...
# 2745  https://postmates.com/store/cupcakin-bake-shop...
# 2746  https://postmates.com/store/poke-bar-berkeley/...
# 2747  https://postmates.com/store/five-guys-ca-1624-...
# 2748  https://postmates.com/store/tp-tea/N-fCyUePQAm...
#
#                  Delivery Address        Geoid
# 0       7192 Saroni Dr Oakland CA  60014045023
# 1       7192 Saroni Dr Oakland CA  60014045023
# 2       7192 Saroni Dr Oakland CA  60014045023
# 3       7192 Saroni Dr Oakland CA  60014045023
# 4       7192 Saroni Dr Oakland CA  60014045023
# ...                           ...          ...
# 2744  9957 Medford Ave Oakland CA  60014093003
# 2745  9957 Medford Ave Oakland CA  60014093003
# 2746  9957 Medford Ave Oakland CA  60014093003
# 2747  9957 Medford Ave Oakland CA  60014093003
# 2748  9957 Medford Ave Oakland CA  60014093003
#
# [49385 rows x 6 columns]

# %%
# Print percent where Wait Time is not NaN
print("Wait time complete:")
print(df['Wait Time'].count() / len(df['Wait Time']) * 100)
# Do the same for Name
print("Name Complete")
print(df['Name'].count() / len(df['Name']) * 100)
# Do the same for Delivery Fee
print("Delivery Fee Complete")
print(df['Delivery Fee'].count() / len(df['Delivery Fee']) * 100)
# Do the same for Link
print("Link Complete")
print(df['Link'].count() / len(df['Link']) * 100)
# Do the same for Delivery Address (sanity check)
print("Delivery Address Complete")
print(df['Delivery Address'].count() / len(df['Delivery Address']) * 100)
# Do the same for Geoid
print("Geoid Complete")
print(df['Geoid'].count() / len(df['Geoid']) * 100)
# Out:
# Wait time complete:
# 99.41885187810064
# Name Complete
# 100.0
# Delivery Fee Complete
# 97.03553710640882
# Link Complete
# 100.0
# Delivery Address Complete
# 100.0
# Geoid Complete
# 100.0
