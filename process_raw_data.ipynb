# %%
import pandas as pd
import os

# %%
# Folder to read all files from
raw_folder = "11-19-2021 11am ET"
# Get list of file names in folder
file_list = os.listdir(raw_folder)
# Loop over files in folder and combine to one dataframe
df = pd.DataFrame()
for file in file_list:
    # Read in file
    file_df = pd.read_csv(raw_folder+'/'+file)
    # Combine to one dataframe
    df = df.append(file_df)
df
# Out:
#                                       Name  Wait Time  Delivery Fee  \
# 0         Pressed Acai Bowls - College Ave        NaN          7.99
# 1                   Dirty Burger (Oakland)        NaN          3.99
# 2    Toasty's Breakfast Burritos (Oakland)        NaN          3.99
# 3          Brekkie Bagels (2353 E 12th St)        NaN          3.99
# 4       Starbucks (Estuary Cove - Oakland)        NaN          4.99
# ..                                     ...        ...           ...
# 758                      Wooden Table Cafe        NaN          4.99
# 759                      Blackberry Bistro        NaN          5.99
# 760                             Donut Farm        NaN          3.99
# 761                     A Taste of Denmark        NaN          4.99
# 762        Carl's Jr. (3770 Telegraph Ave)        NaN          3.99
#
#                                                   Link  \
# 0    https://postmates.com/store/pressed-acai-bowls...
# 1    https://postmates.com/store/dirty-burger-oakla...
# 2    https://postmates.com/store/toastys-breakfast-...
# 3    https://postmates.com/store/brekkie-bagels-235...
# 4    https://postmates.com/store/starbucks-estuary-...
# ..                                                 ...
# 758  https://postmates.com/store/wooden-table-cafe/...
# 759  https://postmates.com/store/blackberry-bistro/...
# 760  https://postmates.com/store/donut-farm/XIw3Efu...
# 761  https://postmates.com/store/a-taste-of-denmark...
# 762  https://postmates.com/store/carls-jr-3770-tele...
#
#                    Delivery Address        Geoid
# 0          555 Julie Way Oakland CA  60014073002
# 1          555 Julie Way Oakland CA  60014073002
# 2          555 Julie Way Oakland CA  60014073002
# 3          555 Julie Way Oakland CA  60014073002
# 4          555 Julie Way Oakland CA  60014073002
# ..                              ...          ...
# 758  2900 Telegraph Ave Berkeley CA  60014236012
# 759  2900 Telegraph Ave Berkeley CA  60014236012
# 760  2900 Telegraph Ave Berkeley CA  60014236012
# 761  2900 Telegraph Ave Berkeley CA  60014236012
# 762  2900 Telegraph Ave Berkeley CA  60014236012
#
# [30742 rows x 6 columns]

# %%
# Count rows where Wait Time is not NaN
df['Wait Time'].count()
# Out:
# 0
