# %%
import pandas as pd
import os

# %%
# Folder to read all files from
raw_folder = "11-19-2021 9pm ET"
# Get list of file names in folder
file_list = os.listdir(raw_folder)
# Loop over files in folder and combine to one dataframe
df = pd.DataFrame()
for file in file_list:
    # Read in file
    file_df = pd.read_csv(raw_folder+'/'+file)
    # Combine to one dataframe
    df = df.append(file_df)
df
# Out:
#                                                    Name  Wait Time  \
# 0                            Philly's Best (Jingletown)  50–60 min
# 1                       Burger Latino (5333 Adeline St)  35–45 min
# 2                     iLava Hawaiian Barbecue (Adeline)  35–45 min
# 3         Philly Fresh Cheesesteaks (5333 Adeline St ,)  35–45 min
# 4     Freddie Parker’s Pasta & Salad Shop - Oakland ...  35–45 min
# ...                                                 ...        ...
# 2205                      Quickly (15000 Farnsworth St)  40–50 min
# 2206                            Theo’s CheeseSteak Shop  45–55 min
# 2207                     Ohana Hawaiian BBQ San Leandro  35–45 min
# 2208                                 Scend's Restaurant  40–50 min
# 2209                                       Saigon House  45–55 min
#
#       Delivery Fee                                               Link  \
# 0             5.99  https://postmates.com/store/phillys-best-jingl...
# 1             2.99  https://postmates.com/store/burger-latino-5333...
# 2             2.99  https://postmates.com/store/ilava-hawaiian-bar...
# 3             2.99  https://postmates.com/store/philly-fresh-chees...
# 4             2.99  https://postmates.com/store/freddie-parkers-pa...
# ...            ...                                                ...
# 2205          5.99  https://postmates.com/store/quickly-15000-farn...
# 2206          4.99  https://postmates.com/store/theos-cheesesteak-...
# 2207          3.99  https://postmates.com/store/ohana-hawaiian-bbq...
# 2208          2.99  https://postmates.com/store/scends-restaurant/...
# 2209          4.99  https://postmates.com/store/saigon-house/K8_-g...
#
#                  Delivery Address        Geoid
# 0     3046 Wheeler St Berkeley CA  60014239011
# 1     3046 Wheeler St Berkeley CA  60014239011
# 2     3046 Wheeler St Berkeley CA  60014239011
# 3     3046 Wheeler St Berkeley CA  60014239011
# 4     3046 Wheeler St Berkeley CA  60014239011
# ...                           ...          ...
# 2205  9957 Medford Ave Oakland CA  60014093003
# 2206  9957 Medford Ave Oakland CA  60014093003
# 2207  9957 Medford Ave Oakland CA  60014093003
# 2208  9957 Medford Ave Oakland CA  60014093003
# 2209  9957 Medford Ave Oakland CA  60014093003
#
# [47682 rows x 6 columns]

# %%
# Print percent where Wait Time is not NaN
print("Wait time complete:")
print(df['Wait Time'].count() / len(df['Wait Time']) * 100)
# Do the same for Name
print("Name Complete")
print(df['Name'].count() / len(df['Name']) * 100)
# Do the same for Delivery Fee
print("Delivery Fee Complete")
print(df['Delivery Fee'].count() / len(df['Delivery Fee']) * 100)
# Do the same for Link
print("Link Complete")
print(df['Link'].count() / len(df['Link']) * 100)
# Do the same for Delivery Address (sanity check)
print("Delivery Address Complete")
print(df['Delivery Address'].count() / len(df['Delivery Address']) * 100)
# Do the same for Geoid
print("Geoid Complete")
print(df['Geoid'].count() / len(df['Geoid']) * 100)
# Out:
# Wait time complete:
# 94.88905666708611
# Name Complete
# 99.29742879912754
# Delivery Fee Complete
# 96.84367266473721
# Link Complete
# 100.0
# Delivery Address Complete
# 100.0
# Geoid Complete
# 100.0

# %%
# Read in OAK_Berk_geocodio_filtered.csv
oak_berk_geocodio_filtered = pd.read_csv('OAK_Berk_geocodio_filtered.csv')
oak_berk_geocodio_filtered
# Out:
#      Unnamed: 0  Countyfp  Blkgrpce Funcstat        Geoid   Latitude  \
# 0             0         1         3        S  60014072003  37.781047
# 1             1         1         1        S  60014036001  37.813905
# 2             2         1         2        S  60014036002  37.814329
# 3             3         1         1        S  60014038001  37.815794
# 4             4         1         2        S  60014038002  37.813742
# ..          ...       ...       ...      ...          ...        ...
# 388         403         1         1        S  60014236011  37.859920
# 389         404         1         2        S  60014236012  37.857546
# 390         405         1         1        S  60014236021  37.863800
# 391         406         1         2        S  60014236022  37.864445
# 392         407         1         2        S  60014237002  37.859562
#
#       Longitude  Mtfcc       Namelsad  Statefp  ...  Number          Street  \
# 0   -122.220743  G5030  Block Group 3        6  ...  3440.0       E 18th St
# 1   -122.251403  G5030  Block Group 1        6  ...   327.0  Macarthur Blvd
# 2   -122.254174  G5030  Block Group 2        6  ...   382.0       Jayne Ave
# 3   -122.236363  G5030  Block Group 1        6  ...  4014.0   Lakeshore Ave
# 4   -122.241825  G5030  Block Group 2        6  ...   536.0       Prince St
# ..          ...    ...            ...      ...  ...     ...             ...
# 388 -122.258048  G5030  Block Group 1        6  ...  2455.0       Stuart St
# 389 -122.259594  G5030  Block Group 2        6  ...  2900.0   Telegraph Ave
# 390 -122.261811  G5030  Block Group 1        6  ...  2321.0        Blake St
# 391 -122.256132  G5030  Block Group 2        6  ...  2527.0   Hillegass Ave
# 392 -122.248932  G5030  Block Group 2        6  ...  2920.0      Avalon Ave
#
#      Unit Type  Unit Number      City  State          County    Zip Country  \
# 0          NaN          NaN   Oakland     CA  Alameda County  94601      US
# 1          NaN          NaN   Oakland     CA  Alameda County  94610      US
# 2          NaN          NaN   Oakland     CA  Alameda County  94610      US
# 3          NaN          NaN   Oakland     CA  Alameda County  94610      US
# 4          NaN          NaN   Oakland     CA  Alameda County  94610      US
# ..         ...          ...       ...    ...             ...    ...     ...
# 388        NaN          NaN  Berkeley     CA  Alameda County  94705      US
# 389        NaN          NaN  Berkeley     CA  Alameda County  94705      US
# 390        NaN          NaN  Berkeley     CA  Alameda County  94704      US
# 391        NaN          NaN  Berkeley     CA  Alameda County  94704      US
# 392        NaN          NaN  Berkeley     CA  Alameda County  94705      US
#
#        Source
# 0     Alameda
# 1     Alameda
# 2     Alameda
# 3     Alameda
# 4     Alameda
# ..        ...
# 388  Berkeley
# 389  Berkeley
# 390  Berkeley
# 391  Berkeley
# 392   Alameda
#
# [393 rows x 27 columns]

# %%
# Left join df with oak_berk_geocodio_filtered on Geoid
df_merged = df.merge(oak_berk_geocodio_filtered, on='Geoid', how='left')
df_merged.columns
df_merged.to_csv(raw_folder + '/' + 'df_merged.csv')

# %%
# Get uinque list of name, delivery address combinations
rest_delivery = df_merged[['Name', 'Delivery Address']].drop_duplicates()
# Get distinct rows
percent_unique_rest_delivery_address = rest_delivery.drop_duplicates(subset=None).shape[0]/df_merged.shape[0]
# Print percent of unique combinations rounded to 2 decimal places
print("Percent of unique combinations:")
print(round(percent_unique_rest_delivery_address * 100, 2))
# Out:
# Percent of unique combinations:
# 98.04

# %%
# Get number of unique links
unique_links = df_merged['Link'].drop_duplicates().shape[0]
# Print number of unique links
print("Number of unique links:")
print(unique_links)
# Out:
# Number of unique links:
# 1473

# %%
# Get top 10 links
df_merged['Link'].value_counts().head(10)
# Out:
# https://postmates.com/store/phillys-best-jingletown/1KLs4MxmVZCQetIxNTprTQ                      348
# https://postmates.com/store/toastys-breakfast-burritos-oakland/YOWaRzZbUMSMGnPj8o9fSg           347
# https://postmates.com/store/shake-shack-1954-telegraph-avenue/W7fSKEGQQfyE1wOrUGiv_w            329
# https://postmates.com/store/dirty-burger-oakland/ysCyucfnU3mFD81lNrV4Bw                         325
# https://postmates.com/store/savemore-market-%26-liquor/DexkeUbyR86zELCtTXsK_A                   312
# https://postmates.com/store/philly-fresh-cheesesteaks-5333-adeline-st/G8cVN2B6XECblewlDZHmMg    309
# https://postmates.com/store/mijori-japanese-restaurant/SbICoOCvSuSj2OQsm9XYLg                   303
# https://postmates.com/store/tender-greens-2071-university-ave/P-jHqO02RuG9N2eoMiCcgQ            301
# https://postmates.com/store/lil-burma-2353-e-12th-st/ABiiKYxkXqyIkHo6sLBOqA                     299
# https://postmates.com/store/burger-latino-5333-adeline-st/DutD7hRLUJKXSAJUksYlSQ                293
# Name: Link, dtype: int64
